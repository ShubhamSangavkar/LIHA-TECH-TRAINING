# %% [markdown]
# 1

# %%
t=(10,20,30,40)
print(t)
# Out:
# (10, 20, 30, 40)

# %% [markdown]
# 2

# %%
t=(1,2,3,4,5)
print("Length =",len(t))
# Out:
# Length = 5

# %% [markdown]
# 3

# %%
t=(1,2,2,3,2,4)
print("Occurrences of 2 =",t.count(2))
# Out:
# Occurrences of 2 = 3

# %% [markdown]
# 4

# %%
t=(10,20,30,40)
print("Index =",t.index(30))
# Out:
# Index = 2

# %% [markdown]
# 5

# %%
t=(1,2,3); a=[4,5,6]
print("Tuple to List =",list(t))
print("List to Tuple =",tuple(a))
# Out:
# Tuple to List = [1, 2, 3]
# List to Tuple = (4, 5, 6)

# %% [markdown]
# 6

# %%
t=(8,3,15,1,9)
print("Maximum =",max(t))
print("Minimum =",min(t))
# Out:
# Maximum = 15
# Minimum = 1

# %% [markdown]
# 7

# %%
t=(10,20,30,40,50)
print(t[1:4])
# Out:
# (20, 30, 40)

# %% [markdown]
# 8

# %%
print((1,2,3)+(4,5))
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# 9

# %%
t=(10,20,30); x=20
if x in t: print(x,"exists in the tuple")
else: print(x,"does not exist in the tuple")
# Out:
# 20 exists in the tuple

# %% [markdown]
# 10

# %%
element=5; repeat=4
print((element,)*repeat)
# Out:
# (5, 5, 5, 5)

# %% [markdown]
# 11

# %%
data=(101,"Amit",85.5)
roll,name,marks=data
print("Roll =",roll)
print("Name =",name)
print("Marks =",marks)
# Out:
# Roll = 101
# Name = Amit
# Marks = 85.5

# %% [markdown]
# 12

# %%
t=(5,2,8,1,4)
print(tuple(sorted(t)))
# Out:
# (1, 2, 4, 5, 8)

# %% [markdown]
# 13

# %%
t=(1,2,2,3,1,4); r=()
for x in t:
    if x not in r: r+=(x,)
print(r)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# 14

# %%
t=(1,2,(10,20,30))
print("Inner tuple =",t[2])
print("Second inner element =",t[2][1])
# Out:
# Inner tuple = (10, 20, 30)
# Second inner element = 20

# %% [markdown]
# B1

# %%
t=(1,2,3,4)
print(t[::-1])
# Out:
# (4, 3, 2, 1)

# %% [markdown]
# B2

# %%
a=(1,2,3); b=(4,5,6); r=()
for i in range(len(a)): r+=(a[i]+b[i],)
print(r)
# Out:
# (5, 7, 9)

# %% [markdown]
# B3

# %%
t=(1,2,2,3,4,4,4); r=()
for x in t:
    if t.count(x)>1 and x not in r: r+=(x,)
print(r)
# Out:
# (2, 4)

# %% [markdown]
# B4

# %%
a=[("A",75),("B",92),("C",80)]
print(sorted(a,key=lambda x:x[1]))
# Out:
# [('A', 75), ('C', 80), ('B', 92)]

# %% [markdown]
# B5

# %%
t=((1,"A"),(2,"B"),(3,"C")); n=(); l=()
for p in t:
    n+=(p[0],); l+=(p[1],)
print("Numbers =",n)
print("Letters =",l)
# Out:
# Numbers = (1, 2, 3)
# Letters = ('A', 'B', 'C')

# %% [markdown]
# B6

# %%
t=(10,20,30,40,50)
first,*middle,last=t
print("First =",first)
print("Middle =",tuple(middle))
print("Last =",last)
# Out:
# First = 10
# Middle = (20, 30, 40)
# Last = 50
