# %% [markdown]
# 1

# %%
a=[10,20,30,40]
for x in a: print(x)
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# 2

# %%
a=[10,20,30,40]
total=0
for x in a: total+=x
print("Sum =",total)
print("Average =",total/len(a))
# Out:
# Sum = 100
# Average = 25.0

# %% [markdown]
# 3

# %%
a=[8,3,15,1,9]
large=small=a[0]
for x in a:
    if x>large: large=x
    if x<small: small=x
print("Largest =",large)
print("Smallest =",small)
# Out:
# Largest = 15
# Smallest = 1

# %% [markdown]
# 4

# %%
a=[1,2,3,4,5,6]
even=odd=0
for x in a:
    if x%2==0: even+=1
    else: odd+=1
print("Even count =",even)
print("Odd count =",odd)
# Out:
# Even count = 3
# Odd count = 3

# %% [markdown]
# 5

# %%
a=[1,2,2,3,1,4]
r=[]
for x in a:
    if x not in r: r.append(x)
print(r)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 6

# %%
a=[10,20,30,40]
r=[]
for i in range(len(a)-1,-1,-1): r.append(a[i])
print(r)
# Out:
# [40, 30, 20, 10]

# %% [markdown]
# 7

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 8

# %%
a=[10,40,20,30,50]
large=a[0]
second=None
for x in a:
    if x>large:
        second=large; large=x
    elif x!=large and (second is None or x>second): second=x
print("Second largest =",second)
# Out:
# Second largest = 40

# %% [markdown]
# 9

# %%
a=[5,2,8,1,4]
print("Ascending =",sorted(a))
print("Descending =",sorted(a,reverse=True))
# Out:
# Ascending = [1, 2, 4, 5, 8]
# Descending = [8, 5, 4, 2, 1]

# %% [markdown]
# 10

# %%
a=[10,20,30,40]
search=30
for i in range(len(a)):
    if a[i]==search:
        print(search,"found at index",i)
        break
# Out:
# 30 found at index 2

# %% [markdown]
# 11

# %%
a=[10,20,40]
a.insert(2,30)
print(a)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 12

# %%
a=[1,2,3,2,4,2]
r=[]
for x in a:
    if x!=2: r.append(x)
print(r)
# Out:
# [1, 3, 4]

# %% [markdown]
# 13

# %%
a=[-5,3,-2,7,0,-1]
p=[]; n=[]
for x in a:
    if x>0: p.append(x)
    elif x<0: n.append(x)
print("Positive =",p)
print("Negative =",n)
# Out:
# Positive = [3, 7]
# Negative = [-5, -2, -1]

# %% [markdown]
# 14

# %%
a=[1,2,3,4]; b=[3,4,5,6]; r=[]
for x in a:
    if x in b and x not in r: r.append(x)
print(r)
# Out:
# [3, 4]

# %% [markdown]
# 15

# %%
a=[1,2,3,4,5]
r=[]
for x in a: r.append(x*x)
print(r)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 16

# %%
a=[1,2,3,4,5]; n=2
n=n%len(a)
print(a[n:]+a[:n])
# Out:
# [3, 4, 5, 1, 2]

# %% [markdown]
# B1

# %%
a=[3,1,3,2,1,4]
r=[]
for x in a:
    if x not in r: r.append(x)
print(r)
# Out:
# [3, 1, 2, 4]

# %% [markdown]
# B2

# %%
a=[1,2,3,4,5,6,7,8]; size=3
r=[]
for i in range(0,len(a),size): r.append(a[i:i+size])
print(r)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8]]

# %% [markdown]
# B3

# %%
a=[0,1,0,3,12]; r=[]
for x in a:
    if x!=0: r.append(x)
for x in a:
    if x==0: r.append(x)
print(r)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# B4

# %%
a=[1,2,4,5,6]; n=6
expected=n*(n+1)//2
total=0
for x in a: total+=x
print("Missing number =",expected-total)
# Out:
# Missing number = 3

# %% [markdown]
# B5

# %%
a=[2,7,11,15]; target=9
for i in range(len(a)):
    for j in range(i+1,len(a)):
        if a[i]+a[j]==target: print("Pair =",(a[i],a[j]))
# Out:
# Pair = (2, 7)

# %% [markdown]
# B6

# %%
a=[1,2,3]; b=[4,5,6]; r=[]
for i in range(len(a)): r.append(a[i]+b[i])
print(r)
# Out:
# [5, 7, 9]

# %% [markdown]
# B7

# %%
a=[1,2,2,3,3,3]; freq={}
for x in a:
    if x in freq: freq[x]+=1
    else: freq[x]=1
for x in freq: print(x,"->",freq[x])
# Out:
# 1 -> 1
# 2 -> 2
# 3 -> 3

# %% [markdown]
# B8

# %%
a=[1,2,3,4,5]; n=3
n=n%len(a)
print(a[n:]+a[:n])
# Out:
# [4, 5, 1, 2, 3]

# %% [markdown]
# B9

# %%
a=[1,2,2,3]; b=[2,2,4]; temp=b.copy(); r=[]
for x in a:
    if x in temp: r.append(x); temp.remove(x)
print(r)
# Out:
# [2, 2]

# %% [markdown]
# B10

# %%
a=[[1,2,3],[4,5,6]]; r=[]
for j in range(len(a[0])):
    row=[]
    for i in range(len(a)): row.append(a[i][j])
    r.append(row)
print(r)
# Out:
# [[1, 4], [2, 5], [3, 6]]
