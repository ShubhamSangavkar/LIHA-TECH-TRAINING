# %%
a = 10
b = 20.3
c = "ddf"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
import math 
math.sqrt(25)
# Out:
# 5.0

# %%
math.factorial(5)
# Out:
# 120

# %%
# Check PEP 8 python style guide

# %%
bank_name='sbi'
bank_name
# Out:
# 'sbi'

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# String 
name = "Shubham"
type(name)
# Out:
# str

# %%
"it is amol's book"
# Out:
# "it is amol's book"

# %%
print("he said , \"I can't come tomorrow\"")
# Out:
# he said , "I can't come tomorrow"

# %%
s="PYTHON"
s[-2]
# Out:
# 'O'

# %%
'\u0950'
# Out:
# 'ॐ'

# %%
a = "python"
a.index("o")
# Out:
# 4

# %%
d = "*#  python is simple *#$$"
d.strip(" $#*")
# Out:
# 'python is simple'

# %%
d = 'python  is   simple'
d = d.split()
" ".join(d)
# Out:
# 'python is simple'

# %%
date = ['08', 'August','2026']

" / " .join(date)
# Out:
# '08 / August / 2026'

# %%
nm="PrATHmesH"
nm.swapcase()
# Out:
# 'pRathMESh'

# %% [markdown]
# LIST

# %%
k = [10, 30,20,40]
k
# Out:
# [10, 30, 20, 40]

# %%
# Append vs Extends 

k.append("abc")
print(k)
k.extend("abc")
k
# Out:
# [10, 30, 20, 40, 'abc']
# [10, 30, 20, 40, 'abc', 'a', 'b', 'c']

# %%
k.pop(1)
# Out:
# 30

# %%
f = [1,2,3,4,5]
f_copy = f.copy()
f_copy
# Out:
# [1, 2, 3, 4, 5]

# %%
f[2]=30
f
# Out:
# [1, 2, 30, 4, 5]

# %%
f_copy
# Out:
# [1, 2, 3, 4, 5]

# %%
id(f),id(f_copy)
# Out:
# (2167692177408, 2167692143680)

# %%
new_copy = f
new_copy
# Out:
# [1, 2, 30, 4, 5]

# %%
new_copy.append(500)
new_copy,f
# Out:
# ([1, 2, 30, 4, 5, 500], [1, 2, 30, 4, 5, 500])

# %%
c=[10,15,20,30]
c
# Out:
# [10, 15, 20, 30]

# %%
c.insert(4,"C++")
c
# Out:
# [10, 15, 20, 30, 'C++']

# %%
h = [30,49,48,23,3]
h.sort(reverse=True)
h
# Out:
# [49, 48, 30, 23, 3]

# %% [markdown]
# Tuple

# %%
t = (1,3,4)
t
# Out:
# (1, 3, 4)

# %% [markdown]
# Set

# %%
s = set()
s.add(2)
s.add(3)
s
# Out:
# {2, 3}

# %%
s1 = {1,3,4,52,441,44,5,2,2,2,2}
s1
# Out:
# {1, 2, 3, 4, 5, 44, 52, 441}

# %%
s3=set()
s3.add(100)
s3
# Out:
# {100}

# %%
s
# Out:
# {2, 3}

# %%
print("ABC")
# Out:
# ABC
